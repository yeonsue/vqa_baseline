# %% [markdown]
# ## Import

# %%
# !pip install transformers
# !pip install timm
# Out:
# Collecting transformers
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 46.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 79.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.2 tokenizers-0.13.3 transformers-4.31.0
# Collecting timm
#   Downloading timm-0.9.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-0.9.5

# %%
import os
import pandas as pd

import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import torchvision.models as models # 이미지
from torchvision import transforms
from PIL import Image

from transformers import BertTokenizer, BertModel # 텍스트

from tqdm.auto import tqdm
import timm
from timm.data import resolve_data_config
from timm.data.transforms_factory import create_transform

# %%
# !wget —load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget —quiet —save-cookies ~/cookies.txt —keep-session-cookies —no-check-certificate 'https://docs.google.com/uc?export=download&id=1a9XB3r83ZCFWLOHBp8ooz3zQFl9rEIei' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1a9XB3r83ZCFWLOHBp8ooz3zQFl9rEIei" -O open.zip && rm -rf ~/cookies.txt
# Out:
# --2023-08-16 08:53:23--  http://xn--quiet-3u3b/
# Resolving xn--quiet-3u3b (xn--quiet-3u3b)... failed: Name or service not known.
# wget: unable to resolve host address ‘xn--quiet-3u3b’
# --2023-08-16 08:53:23--  http://xn--save-cookies-w19f/
# Resolving xn--save-cookies-w19f (xn--save-cookies-w19f)... failed: Name or service not known.
# wget: unable to resolve host address ‘xn--save-cookies-w19f’
# /root/cookies.txt: Scheme missing.
# --2023-08-16 08:53:23--  http://xn--keep-session-cookies-ou2l/
# Resolving xn--keep-session-cookies-ou2l (xn--keep-session-cookies-ou2l)... failed: Name or service not known.
# wget: unable to resolve host address ‘xn--keep-session-cookies-ou2l’
# --2023-08-16 08:53:23--  http://xn--no-check-certificate-ou2l/
# Resolving xn--no-check-certificate-ou2l (xn--no-check-certificate-ou2l)... failed: Name or service not known.
# wget: unable to resolve host address ‘xn--no-check-certificate-ou2l’
# --2023-08-16 08:53:23--  https://docs.google.com/uc?export=download&id=1a9XB3r83ZCFWLOHBp8ooz3zQFl9rEIei
# Resolving docs.google.com (docs.google.com)... 74.125.68.113, 74.125.68.100, 74.125.68.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.68.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘STDOUT’
#
# -                       [ <=>                ]   2.22K  --.-KB/s    in 0s
#
# 2023-08-16 08:53:24 (39.3 MB/s) - written to stdout [2270]
#
# FINISHED --2023-08-16 08:53:24--
# Total wall clock time: 1.5s
# Downloaded: 1 files, 2.2K in 0s (39.3 MB/s)
# --2023-08-16 08:53:24--  http://xn--load-cookies-w19f/
# Resolving xn--load-cookies-w19f (xn--load-cookies-w19f)... failed: Name or service not known.
# wget: unable to resolve host address ‘xn--load-cookies-w19f’
# /root/cookies.txt: Scheme missing.
# --2023-08-16 08:53:24--  https://docs.google.com/uc?export=download&confirm=t&id=1a9XB3r83ZCFWLOHBp8ooz3zQFl9rEIei
# Resolving docs.google.com (docs.google.com)... 74.125.68.113, 74.125.68.100, 74.125.68.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.68.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5lr8o3q53o5nuat28r8qcfabej0ro19t/1692175950000/00770885000471893693/*/1a9XB3r83ZCFWLOHBp8ooz3zQFl9rEIei?e=download&uuid=799fece8-c999-4446-bc51-e9456afe5b7d [following]
# Warning: wildcards not supported in HTTP.
# --2023-08-16 08:53:25--  https://doc-0s-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5lr8o3q53o5nuat28r8qcfabej0ro19t/1692175950000/00770885000471893693/*/1a9XB3r83ZCFWLOHBp8ooz3zQFl9rEIei?e=download&uuid=799fece8-c999-4446-bc51-e9456afe5b7d
# Resolving doc-0s-9o-docs.googleusercontent.com (doc-0s-9o-docs.googleusercontent.com)... 142.250.4.132, 2404:6800:4003:c06::84
# Connecting to doc-0s-9o-docs.googleusercontent.com (doc-0s-9o-docs.googleusercontent.com)|142.250.4.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5871222183 (5.5G) [application/zip]
# Saving to: ‘open.zip’
#
# open.zip            100%[===================>]   5.47G  78.9MB/s    in 83s
#
# 2023-08-16 08:54:49 (67.7 MB/s) - ‘open.zip’ saved [5871222183/5871222183]
#
# FINISHED --2023-08-16 08:54:49--
# Total wall clock time: 1m 25s
# Downloaded: 1 files, 5.5G in 1m 23s (67.7 MB/s)

# %%
# !unzip open.zip -d ./open
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./open/image/test/test_05880.jpg
#   inflating: ./open/image/test/test_07566.jpg
#   inflating: ./open/image/test/test_09290.jpg
#   inflating: ./open/image/test/test_01284.jpg
#   inflating: ./open/image/test/test_00037.jpg
#   inflating: ./open/image/test/test_07701.jpg
#   inflating: ./open/image/test/test_03156.jpg
#   inflating: ./open/image/test/test_00986.jpg
#   inflating: ./open/image/test/test_01531.jpg
#   inflating: ./open/image/test/test_04526.jpg
#   inflating: ./open/image/test/test_05109.jpg
#   inflating: ./open/image/test/test_10827.jpg
#   inflating: ./open/image/test/test_07676.jpg
#   inflating: ./open/image/test/test_01460.jpg
#   inflating: ./open/image/test/test_09486.jpg
#   inflating: ./open/image/test/test_08309.jpg
#   inflating: ./open/image/test/test_03076.jpg
#   inflating: ./open/image/test/test_07918.jpg
#   inflating: ./open/image/test/test_09718.jpg
#   inflating: ./open/image/test/test_01645.jpg
#   inflating: ./open/image/test/test_08581.jpg
#   inflating: ./open/image/test/test_03334.jpg
#   inflating: ./open/image/test/test_01288.jpg
#   inflating: ./open/image/test/test_00134.jpg
#   inflating: ./open/image/test/test_07582.jpg
#   inflating: ./open/image/test/test_11224.jpg
#   inflating: ./open/image/test/test_10954.jpg
#   inflating: ./open/image/test/test_10013.jpg
#   inflating: ./open/image/test/test_08773.jpg
#   inflating: ./open/image/test/test_06890.jpg
#   inflating: ./open/image/test/test_06641.jpg
#   inflating: ./open/image/test/test_00810.jpg
#   inflating: ./open/image/test/test_08714.jpg
#   inflating: ./open/image/test/test_11653.jpg
#   inflating: ./open/image/test/test_01253.jpg
#   inflating: ./open/image/test/test_02401.jpg
#   inflating: ./open/image/test/test_10242.jpg
#   inflating: ./open/image/test/test_07006.jpg
#   inflating: ./open/image/test/test_11701.jpg
#   inflating: ./open/image/test/test_04653.jpg
#   inflating: ./open/image/test/test_01196.jpg
#   inflating: ./open/image/test/test_06166.jpg
#   inflating: ./open/image/test/test_08988.jpg
#   inflating: ./open/image/test/test_10633.jpg
#   inflating: ./open/image/test/test_07741.jpg
#   inflating: ./open/image/test/test_05100.jpg
#   inflating: ./open/image/test/test_00142.jpg
#   inflating: ./open/image/test/test_02426.jpg
#   inflating: ./open/image/test/test_02447.jpg
#   inflating: ./open/image/test/test_09441.jpg
#   inflating: ./open/image/test/test_05625.jpg
#   inflating: ./open/image/test/test_01829.jpg
#   inflating: ./open/image/test/test_05286.jpg
#   inflating: ./open/image/test/test_05886.jpg
#   inflating: ./open/image/test/test_09124.jpg
#   inflating: ./open/image/test/test_00469.jpg
#   inflating: ./open/image/test/test_09665.jpg
#   inflating: ./open/image/test/test_02425.jpg
#   inflating: ./open/image/test/test_01317.jpg
#   inflating: ./open/image/test/test_06088.jpg
#   inflating: ./open/image/test/test_03088.jpg
#   inflating: ./open/image/test/test_11187.jpg
#   inflating: ./open/image/test/test_07458.jpg
#   inflating: ./open/image/test/test_02860.jpg
#   inflating: ./open/image/test/test_03065.jpg
#   inflating: ./open/image/test/test_00106.jpg
#   inflating: ./open/image/test/test_06497.jpg
#   inflating: ./open/image/test/test_03481.jpg
#   inflating: ./open/image/test/test_00239.jpg
#   inflating: ./open/image/test/test_03894.jpg
#   inflating: ./open/image/test/test_08826.jpg
#   inflating: ./open/image/test/test_07260.jpg
#   inflating: ./open/image/test/test_01054.jpg
#   inflating: ./open/image/test/test_03136.jpg
#   inflating: ./open/image/test/test_07303.jpg
#   inflating: ./open/image/test/test_09745.jpg
#   inflating: ./open/image/test/test_06028.jpg
#   inflating: ./open/image/test/test_08335.jpg
#   inflating: ./open/image/test/test_00527.jpg
#   inflating: ./open/image/test/test_04696.jpg
#   inflating: ./open/image/test/test_04088.jpg
#   inflating: ./open/image/test/test_04360.jpg
#   inflating: ./open/image/test/test_10678.jpg
#   inflating: ./open/image/test/test_11018.jpg
#   inflating: ./open/image/test/test_01898.jpg
#   inflating: ./open/image/test/test_10848.jpg
#   inflating: ./open/image/test/test_02790.jpg
#   inflating: ./open/image/test/test_08265.jpg
#   inflating: ./open/image/test/test_08123.jpg
#   inflating: ./open/image/test/test_00139.jpg
#   inflating: ./open/image/test/test_06019.jpg
#   inflating: ./open/image/test/test_10649.jpg
#   inflating: ./open/image/test/test_07232.jpg
#   inflating: ./open/image/test/test_09542.jpg
#   inflating: ./open/image/test/test_05791.jpg
#   inflating: ./open/image/test/test_01119.jpg
#   inflating: ./open/image/test/test_07522.jpg
#   inflating: ./open/image/test/test_02152.jpg
#   inflating: ./open/image/test/test_07009.jpg
#   inflating: ./open/image/test/test_08694.jpg
#   inflating: ./open/image/test/test_05505.jpg
#   inflating: ./open/image/test/test_09039.jpg
#   inflating: ./open/image/test/test_09235.jpg
#   inflating: ./open/image/test/test_04351.jpg
#   inflating: ./open/image/test/test_00890.jpg
#   inflating: ./open/image/test/test_08089.jpg
#   inflating: ./open/image/test/test_07630.jpg
#   inflating: ./open/image/test/test_07658.jpg
#   inflating: ./open/image/test/test_03069.jpg
#   inflating: ./open/image/test/test_10369.jpg
#   inflating: ./open/image/test/test_01774.jpg
#   inflating: ./open/image/test/test_03219.jpg
#   inflating: ./open/image/test/test_10274.jpg
#   inflating: ./open/image/test/test_02772.jpg
#   inflating: ./open/image/test/test_07249.jpg
#   inflating: ./open/image/test/test_02210.jpg
#   inflating: ./open/image/test/test_04359.jpg
#   inflating: ./open/image/test/test_07819.jpg
#   inflating: ./open/image/test/test_03188.jpg
#   inflating: ./open/image/test/test_01105.jpg
#   inflating: ./open/image/test/test_09983.jpg
#   inflating: ./open/image/test/test_10187.jpg
#   inflating: ./open/image/test/test_03904.jpg
#   inflating: ./open/image/test/test_05073.jpg
#   inflating: ./open/image/test/test_01893.jpg
#   inflating: ./open/image/test/test_02204.jpg
#   inflating: ./open/image/test/test_00273.jpg
#   inflating: ./open/image/test/test_07202.jpg
#   inflating: ./open/image/test/test_03994.jpg
#   inflating: ./open/image/test/test_02372.jpg
#   inflating: ./open/image/test/test_07697.jpg
#   inflating: ./open/image/test/test_07975.jpg
#   inflating: ./open/image/test/test_05078.jpg
#   inflating: ./open/image/test/test_02383.jpg
#   inflating: ./open/image/test/test_00845.jpg
#   inflating: ./open/image/test/test_02551.jpg
#   inflating: ./open/image/test/test_11235.jpg
#   inflating: ./open/image/test/test_02645.jpg
#   inflating: ./open/image/test/test_11651.jpg
#   inflating: ./open/image/test/test_08336.jpg
#   inflating: ./open/image/test/test_00016.jpg
#   inflating: ./open/image/test/test_03543.jpg
#   inflating: ./open/image/test/test_05972.jpg
#   inflating: ./open/image/test/test_02084.jpg
#   inflating: ./open/image/test/test_09577.jpg
#   inflating: ./open/image/test/test_01351.jpg
#   inflating: ./open/image/test/test_03235.jpg
#   inflating: ./open/image/test/test_08003.jpg
#   inflating: ./open/image/test/test_09090.jpg
#   inflating: ./open/image/test/test_10647.jpg
#   inflating: ./open/image/test/test_04538.jpg
#   inflating: ./open/image/test/test_11167.jpg
#   inflating: ./open/image/test/test_11292.jpg
#   inflating: ./open/image/test/test_03120.jpg
#   inflating: ./open/image/test/test_08164.jpg
#   inflating: ./open/image/test/test_07993.jpg
#   inflating: ./open/image/test/test_06309.jpg
#   inflating: ./open/image/test/test_02875.jpg
#   inflating: ./open/image/test/test_03412.jpg
#   inflating: ./open/image/test/test_00337.jpg
#   inflating: ./open/image/test/test_01071.jpg
#   inflating: ./open/image/test/test_05108.jpg
#   inflating: ./open/image/test/test_03662.jpg
#   inflating: ./open/image/test/test_08321.jpg
#   inflating: ./open/image/test/test_06462.jpg
#   inflating: ./open/image/test/test_08420.jpg
#   inflating: ./open/image/test/test_04588.jpg
#   inflating: ./open/image/test/test_08238.jpg
#   inflating: ./open/image/test/test_01072.jpg
#   inflating: ./open/image/test/test_00281.jpg
#   inflating: ./open/image/test/test_01916.jpg
#   inflating: ./open/image/test/test_07533.jpg
#   inflating: ./open/image/test/test_10318.jpg
#   inflating: ./open/image/test/test_10770.jpg
#   inflating: ./open/image/test/test_11544.jpg
#   inflating: ./open/image/test/test_01978.jpg
#   inflating: ./open/image/test/test_05699.jpg
#   inflating: ./open/image/test/test_10860.jpg
#   inflating: ./open/image/test/test_08031.jpg
#   inflating: ./open/image/test/test_07168.jpg
#   inflating: ./open/image/test/test_06455.jpg
#   inflating: ./open/image/test/test_08324.jpg
#   inflating: ./open/image/test/test_11019.jpg
#   inflating: ./open/image/test/test_01837.jpg
#   inflating: ./open/image/test/test_00836.jpg
#   inflating: ./open/image/test/test_03808.jpg
#   inflating: ./open/image/test/test_10955.jpg
#   inflating: ./open/image/test/test_06556.jpg
#   inflating: ./open/image/test/test_02088.jpg
#   inflating: ./open/image/test/test_03556.jpg
#   inflating: ./open/image/test/test_06335.jpg
#   inflating: ./open/image/test/test_03248.jpg
#   inflating: ./open/image/test/test_00914.jpg
#   inflating: ./open/image/test/test_09587.jpg
#   inflating: ./open/image/test/test_09682.jpg
#   inflating: ./open/image/test/test_07637.jpg
#   inflating: ./open/image/test/test_03507.jpg
#   inflating: ./open/image/test/test_00260.jpg
#   inflating: ./open/image/test/test_05566.jpg
#   inflating: ./open/image/test/test_09969.jpg
#   inflating: ./open/image/test/test_06633.jpg
#   inflating: ./open/image/test/test_07660.jpg
#   inflating: ./open/image/test/test_00745.jpg
#   inflating: ./open/image/test/test_00648.jpg
#   inflating: ./open/image/test/test_06058.jpg
#   inflating: ./open/image/test/test_09418.jpg
#   inflating: ./open/image/test/test_02115.jpg
#   inflating: ./open/image/test/test_01183.jpg
#   inflating: ./open/image/test/test_07268.jpg
#   inflating: ./open/image/test/test_08045.jpg
#   inflating: ./open/image/test/test_11312.jpg
#   inflating: ./open/image/test/test_04855.jpg
#   inflating: ./open/image/test/test_07505.jpg
#   inflating: ./open/image/test/test_05151.jpg
#   inflating: ./open/image/test/test_00732.jpg
#   inflating: ./open/image/test/test_08529.jpg
#   inflating: ./open/image/test/test_06113.jpg
#   inflating: ./open/image/test/test_08081.jpg
#   inflating: ./open/image/test/test_04604.jpg
#   inflating: ./open/image/test/test_10769.jpg
#   inflating: ./open/image/test/test_00507.jpg
#   inflating: ./open/image/test/test_04444.jpg
#   inflating: ./open/image/test/test_04905.jpg
#   inflating: ./open/image/test/test_04892.jpg
#   inflating: ./open/image/test/test_01306.jpg
#   inflating: ./open/image/test/test_07408.jpg
#   inflating: ./open/image/test/test_04430.jpg
#   inflating: ./open/image/test/test_06820.jpg
#   inflating: ./open/image/test/test_04478.jpg
#   inflating: ./open/image/test/test_03946.jpg
#   inflating: ./open/image/test/test_10269.jpg
#   inflating: ./open/image/test/test_08779.jpg
#   inflating: ./open/image/test/test_08249.jpg
#   inflating: ./open/image/test/test_04659.jpg
#   inflating: ./open/image/test/test_04486.jpg
#   inflating: ./open/image/test/test_11635.jpg
#   inflating: ./open/image/test/test_03418.jpg
#   inflating: ./open/image/test/test_06921.jpg
#   inflating: ./open/image/test/test_01761.jpg
#   inflating: ./open/image/test/test_10553.jpg
#   inflating: ./open/image/test/test_06688.jpg
#   inflating: ./open/image/test/test_02665.jpg
#   inflating: ./open/image/test/test_11216.jpg
#   inflating: ./open/image/test/test_03019.jpg
#   inflating: ./open/image/test/test_05723.jpg
#   inflating: ./open/image/test/test_11361.jpg
#   inflating: ./open/image/test/test_03652.jpg
#   inflating: ./open/image/test/test_02427.jpg
#   inflating: ./open/image/test/test_07986.jpg
#   inflating: ./open/image/test/test_00889.jpg
#   inflating: ./open/image/test/test_11526.jpg
#   inflating: ./open/image/test/test_04519.jpg
#   inflating: ./open/image/test/test_09785.jpg
#   inflating: ./open/image/test/test_07256.jpg
#   inflating: ./open/image/test/test_03243.jpg
#   inflating: ./open/image/test/test_05489.jpg
#   inflating: ./open/image/test/test_11263.jpg
#   inflating: ./open/image/test/test_11600.jpg
#   inflating: ./open/image/test/test_02848.jpg
#   inflating: ./open/image/test/test_09435.jpg
#   inflating: ./open/image/test/test_02952.jpg
#   inflating: ./open/image/test/test_11792.jpg
#   inflating: ./open/image/test/test_04325.jpg
#   inflating: ./open/image/test/test_07669.jpg
#   inflating: ./open/image/test/test_01427.jpg
#   inflating: ./open/image/test/test_06446.jpg
#   inflating: ./open/image/test/test_02693.jpg
#   inflating: ./open/image/test/test_05421.jpg
#   inflating: ./open/image/test/test_10335.jpg
#   inflating: ./open/image/test/test_02125.jpg
#   inflating: ./open/image/test/test_01718.jpg
#   inflating: ./open/image/test/test_11586.jpg
#   inflating: ./open/image/test/test_04140.jpg
#   inflating: ./open/image/test/test_10090.jpg
#   inflating: ./open/image/test/test_01399.jpg
#   inflating: ./open/image/test/test_09281.jpg
#   inflating: ./open/image/test/test_10803.jpg
#   inflating: ./open/image/test/test_10400.jpg
#   inflating: ./open/image/test/test_03502.jpg
#   inflating: ./open/image/test/test_00597.jpg
#   inflating: ./open/image/test/test_08929.jpg
#   inflating: ./open/image/test/test_07288.jpg
#   inflating: ./open/image/test/test_01396.jpg
#   inflating: ./open/image/test/test_03490.jpg
#   inflating: ./open/image/test/test_02303.jpg
#   inflating: ./open/image/test/test_04890.jpg
#   inflating: ./open/image/test/test_00697.jpg
#   inflating: ./open/image/test/test_09195.jpg
#   inflating: ./open/image/test/test_04605.jpg
#   inflating: ./open/image/test/test_06886.jpg
#   inflating: ./open/image/test/test_04497.jpg
#   inflating: ./open/image/test/test_03293.jpg
#   inflating: ./open/image/test/test_07879.jpg
#   inflating: ./open/image/test/test_08068.jpg
#   inflating: ./open/image/test/test_09010.jpg
#   inflating: ./open/image/test/test_06995.jpg
#   inflating: ./open/image/test/test_10370.jpg
#   inflating: ./open/image/test/test_02776.jpg
#   inflating: ./open/image/test/test_04311.jpg
#   inflating: ./open/image/test/test_01300.jpg
#   inflating: ./open/image/test/test_09175.jpg
#   inflating: ./open/image/test/test_03067.jpg
#   inflating: ./open/image/test/test_01786.jpg
#   inflating: ./open/image/test/test_09089.jpg
#   inflating: ./open/image/test/test_02650.jpg
#   inflating: ./open/image/test/test_01577.jpg
#   inflating: ./open/image/test/test_00169.jpg
#   inflating: ./open/image/test/test_10162.jpg
#   inflating: ./open/image/test/test_08376.jpg
#   inflating: ./open/image/test/test_09581.jpg
#   inflating: ./open/image/test/test_02262.jpg
#   inflating: ./open/image/test/test_11041.jpg
#   inflating: ./open/image/test/test_08277.jpg
#   inflating: ./open/image/test/test_00209.jpg
#   inflating: ./open/image/test/test_09297.jpg
#   inflating: ./open/image/test/test_03003.jpg
#   inflating: ./open/image/test/test_06320.jpg
#   inflating: ./open/image/test/test_07019.jpg
#   inflating: ./open/image/test/test_09334.jpg
#   inflating: ./open/image/test/test_03955.jpg
#   inflating: ./open/image/test/test_09567.jpg
#   inflating: ./open/image/test/test_10994.jpg
#   inflating: ./open/image/test/test_06492.jpg
#   inflating: ./open/image/test/test_09574.jpg
#   inflating: ./open/image/test/test_02681.jpg
#   inflating: ./open/image/test/test_09319.jpg
#   inflating: ./open/image/test/test_04935.jpg
#   inflating: ./open/image/test/test_04842.jpg
#   inflating: ./open/image/test/test_08656.jpg
#   inflating: ./open/image/test/test_01511.jpg
#   inflating: ./open/image/test/test_00039.jpg
#   inflating: ./open/image/test/test_02058.jpg
#   inflating: ./open/image/test/test_01861.jpg
#   inflating: ./open/image/test/test_01151.jpg
#   inflating: ./open/image/test/test_07017.jpg
#   inflating: ./open/image/test/test_06860.jpg
#   inflating: ./open/image/test/test_09274.jpg
#   inflating: ./open/image/test/test_09459.jpg
#   inflating: ./open/image/test/test_06956.jpg
#   inflating: ./open/image/test/test_04819.jpg
#   inflating: ./open/image/test/test_10867.jpg
#   inflating: ./open/image/test/test_04830.jpg
#   inflating: ./open/image/test/test_09520.jpg
#   inflating: ./open/image/test/test_07418.jpg
#   inflating: ./open/image/test/test_04052.jpg
#   inflating: ./open/image/test/test_08240.jpg
#   inflating: ./open/image/test/test_06802.jpg
#   inflating: ./open/image/test/test_01553.jpg
#   inflating: ./open/image/test/test_08776.jpg
#   inflating: ./open/image/test/test_06507.jpg
#   inflating: ./open/image/test/test_04463.jpg
#   inflating: ./open/image/test/test_09649.jpg
#   inflating: ./open/image/test/test_04180.jpg
#   inflating: ./open/image/test/test_08253.jpg
#   inflating: ./open/image/test/test_05711.jpg
#   inflating: ./open/image/test/test_04617.jpg
#   inflating: ./open/image/test/test_01003.jpg
#   inflating: ./open/image/test/test_09525.jpg
#   inflating: ./open/image/test/test_06424.jpg
#   inflating: ./open/image/test/test_09626.jpg
#   inflating: ./open/image/test/test_00320.jpg
#   inflating: ./open/image/test/test_09720.jpg
#   inflating: ./open/image/test/test_04296.jpg
#   inflating: ./open/image/test/test_00378.jpg
#   inflating: ./open/image/test/test_08692.jpg
#   inflating: ./open/image/test/test_11591.jpg
#   inflating: ./open/image/test/test_08215.jpg
#   inflating: ./open/image/test/test_09704.jpg
#   inflating: ./open/image/test/test_02921.jpg
#   inflating: ./open/image/test/test_09431.jpg
#   inflating: ./open/image/test/test_01008.jpg
#   inflating: ./open/image/test/test_08951.jpg
#   inflating: ./open/image/test/test_06148.jpg
#   inflating: ./open/image/test/test_09852.jpg
#   inflating: ./open/image/test/test_10286.jpg
#   inflating: ./open/image/test/test_08570.jpg
#   inflating: ./open/image/test/test_02100.jpg
#   inflating: ./open/image/test/test_10029.jpg
#   inflating: ./open/image/test/test_11820.jpg
#   inflating: ./open/image/test/test_04151.jpg
#   inflating: ./open/image/test/test_01395.jpg
#   inflating: ./open/image/test/test_02738.jpg
#   inflating: ./open/image/test/test_10316.jpg
#   inflating: ./open/image/test/test_04312.jpg
#   inflating: ./open/image/test/test_03739.jpg
#   inflating: ./open/image/test/test_05066.jpg
#   inflating: ./open/image/test/test_07873.jpg
#   inflating: ./open/image/test/test_01018.jpg
#   inflating: ./open/image/test/test_07545.jpg
#   inflating: ./open/image/test/test_05009.jpg
#   inflating: ./open/image/test/test_00054.jpg
#   inflating: ./open/image/test/test_09285.jpg
#   inflating: ./open/image/test/test_11867.jpg
#   inflating: ./open/image/test/test_05512.jpg
#   inflating: ./open/image/test/test_00638.jpg
#   inflating: ./open/image/test/test_10397.jpg
#   inflating: ./open/image/test/test_00978.jpg
#   inflating: ./open/image/test/test_05780.jpg
#   inflating: ./open/image/test/test_08762.jpg
#   inflating: ./open/image/test/test_04937.jpg
#   inflating: ./open/image/test/test_06925.jpg
#   inflating: ./open/image/test/test_09916.jpg
#   inflating: ./open/image/test/test_00676.jpg
#   inflating: ./open/image/test/test_07119.jpg
#   inflating: ./open/image/test/test_07356.jpg
#   inflating: ./open/image/test/test_08566.jpg
#   inflating: ./open/image/test/test_06773.jpg
#   inflating: ./open/image/test/test_07667.jpg
#   inflating: ./open/image/test/test_08499.jpg
#   inflating: ./open/image/test/test_08101.jpg
#   inflating: ./open/image/test/test_05821.jpg
#   inflating: ./open/image/test/test_08120.jpg
#   inflating: ./open/image/test/test_04573.jpg
#   inflating: ./open/image/test/test_01959.jpg
#   inflating: ./open/image/test/test_02614.jpg
#   inflating: ./open/image/test/test_00200.jpg
#   inflating: ./open/image/test/test_03260.jpg
#   inflating: ./open/image/test/test_09287.jpg
#   inflating: ./open/image/test/test_03426.jpg
#   inflating: ./open/image/test/test_10668.jpg
#   inflating: ./open/image/test/test_10988.jpg
#   inflating: ./open/image/test/test_02439.jpg
#   inflating: ./open/image/test/test_06652.jpg
#   inflating: ./open/image/test/test_07671.jpg
#   inflating: ./open/image/test/test_05522.jpg
#   inflating: ./open/image/test/test_11337.jpg
#   inflating: ./open/image/test/test_00186.jpg
#   inflating: ./open/image/test/test_01740.jpg
#   inflating: ./open/image/test/test_02494.jpg
#   inflating: ./open/image/test/test_00977.jpg
#   inflating: ./open/image/test/test_10298.jpg
#   inflating: ./open/image/test/test_02294.jpg
#   inflating: ./open/image/test/test_00156.jpg
#   inflating: ./open/image/test/test_10470.jpg
#   inflating: ./open/image/test/test_02853.jpg
#   inflating: ./open/image/test/test_01605.jpg
#   inflating: ./open/image/test/test_06438.jpg
#   inflating: ./open/image/test/test_06189.jpg
#   inflating: ./open/image/test/test_01756.jpg
#   inflating: ./open/image/test/test_03265.jpg
#   inflating: ./open/image/test/test_10711.jpg
#   inflating: ./open/image/test/test_06134.jpg
#   inflating: ./open/image/test/test_11613.jpg
#   inflating: ./open/image/test/test_08352.jpg
#   inflating: ./open/image/test/test_02753.jpg
#   inflating: ./open/image/test/test_10524.jpg
#   inflating: ./open/image/test/test_08521.jpg
#   inflating: ./open/image/test/test_06718.jpg
#   inflating: ./open/image/test/test_09333.jpg
#   inflating: ./open/image/test/test_08573.jpg
#   inflating: ./open/image/test/test_07917.jpg
#   inflating: ./open/image/test/test_03396.jpg
#   inflating: ./open/image/test/test_07236.jpg
#   inflating: ./open/image/test/test_01385.jpg
#   inflating: ./open/image/test/test_10283.jpg
#   inflating: ./open/image/test/test_09488.jpg
#   inflating: ./open/image/test/test_00189.jpg
#   inflating: ./open/image/test/test_10851.jpg
#   inflating: ./open/image/test/test_04615.jpg
#   inflating: ./open/image/test/test_00602.jpg
#   inflating: ./open/image/test/test_00882.jpg
#   inflating: ./open/image/test/test_06547.jpg
#   inflating: ./open/image/test/test_00024.jpg
#   inflating: ./open/image/test/test_10156.jpg
#   inflating: ./open/image/test/test_00552.jpg
#   inflating: ./open/image/test/test_05495.jpg
#   inflating: ./open/image/test/test_09835.jpg
#   inflating: ./open/image/test/test_06184.jpg
#   inflating: ./open/image/test/test_03835.jpg
#   inflating: ./open/image/test/test_07564.jpg
#   inflating: ./open/image/test/test_05303.jpg
#   inflating: ./open/image/test/test_00023.jpg
#   inflating: ./open/image/test/test_01676.jpg
#   inflating: ./open/image/test/test_03269.jpg
#   inflating: ./open/image/test/test_01138.jpg
#   inflating: ./open/image/test/test_10790.jpg
#   inflating: ./open/image/test/test_02739.jpg
#   inflating: ./open/image/test/test_10745.jpg
#   inflating: ./open/image/test/test_09331.jpg
#   inflating: ./open/image/test/test_07947.jpg
#   inflating: ./open/image/test/test_08718.jpg
#   inflating: ./open/image/test/test_09922.jpg
#   inflating: ./open/image/test/test_03792.jpg
#   inflating: ./open/image/test/test_08644.jpg
#   inflating: ./open/image/test/test_04886.jpg
#   inflating: ./open/image/test/test_02838.jpg
#   inflating: ./open/image/test/test_04246.jpg
#   inflating: ./open/image/test/test_00000.jpg
#   inflating: ./open/image/test/test_05463.jpg
#   inflating: ./open/image/test/test_04981.jpg
#   inflating: ./open/image/test/test_10349.jpg
#   inflating: ./open/image/test/test_06552.jpg
#   inflating: ./open/image/test/test_03057.jpg
#   inflating: ./open/image/test/test_04034.jpg
#   inflating: ./open/image/test/test_10344.jpg
#   inflating: ./open/image/test/test_04821.jpg
#   inflating: ./open/image/test/test_00358.jpg
#   inflating: ./open/image/test/test_07264.jpg
#   inflating: ./open/image/test/test_09560.jpg
#   inflating: ./open/image/test/test_09365.jpg
#   inflating: ./open/image/test/test_11033.jpg
#   inflating: ./open/image/test/test_00454.jpg
#   inflating: ./open/image/test/test_00307.jpg
#   inflating: ./open/image/test/test_00110.jpg
#   inflating: ./open/image/test/test_04925.jpg
#   inflating: ./open/image/test/test_06600.jpg
#   inflating: ./open/image/test/test_09884.jpg
#   inflating: ./open/image/test/test_02090.jpg
#   inflating: ./open/image/test/test_10244.jpg
#   inflating: ./open/image/test/test_11210.jpg
#   inflating: ./open/image/test/test_05072.jpg
#   inflating: ./open/image/test/test_09129.jpg
#   inflating: ./open/image/test/test_00120.jpg
#   inflating: ./open/image/test/test_09357.jpg
#   inflating: ./open/image/test/test_07687.jpg
#   inflating: ./open/image/test/test_04082.jpg
#   inflating: ./open/image/test/test_05877.jpg
#   inflating: ./open/image/test/test_04186.jpg
#   inflating: ./open/image/test/test_01376.jpg
#   inflating: ./open/image/test/test_07184.jpg
#   inflating: ./open/image/test/test_01973.jpg
#   inflating: ./open/image/test/test_06997.jpg
#   inflating: ./open/image/test/test_06435.jpg
#   inflating: ./open/image/test/test_03453.jpg
#   inflating: ./open/image/test/test_11885.jpg
#   inflating: ./open/image/test/test_09741.jpg
#   inflating: ./open/image/test/test_05235.jpg
#   inflating: ./open/image/test/test_11103.jpg
#   inflating: ./open/image/test/test_04264.jpg
#   inflating: ./open/image/test/test_10963.jpg
#   inflating: ./open/image/test/test_07484.jpg
#   inflating: ./open/image/test/test_11680.jpg
#   inflating: ./open/image/test/test_11863.jpg
#   inflating: ./open/image/test/test_08426.jpg
#   inflating: ./open/image/test/test_07716.jpg
#   inflating: ./open/image/test/test_01747.jpg
#   inflating: ./open/image/test/test_02961.jpg
#   inflating: ./open/image/test/test_11556.jpg
#   inflating: ./open/image/test/test_03900.jpg
#   inflating: ./open/image/test/test_04772.jpg
#   inflating: ./open/image/test/test_02464.jpg
#   inflating: ./open/image/test/test_10149.jpg
#   inflating: ./open/image/test/test_03231.jpg
#   inflating: ./open/image/test/test_02788.jpg
#   inflating: ./open/image/test/test_02609.jpg
#   inflating: ./open/image/test/test_03609.jpg
#   inflating: ./open/image/test/test_03078.jpg
#   inflating: ./open/image/test/test_01938.jpg
#   inflating: ./open/image/test/test_07191.jpg
#   inflating: ./open/image/test/test_05007.jpg
#   inflating: ./open/image/test/test_06093.jpg
#   inflating: ./open/image/test/test_09109.jpg
#   inflating: ./open/image/test/test_04652.jpg
#   inflating: ./open/image/test/test_11625.jpg
#   inflating: ./open/image/test/test_00132.jpg
#   inflating: ./open/image/test/test_08975.jpg
#   inflating: ./open/image/test/test_09755.jpg
#   inflating: ./open/image/test/test_11710.jpg
#   inflating: ./open/image/test/test_01060.jpg
#   inflating: ./open/image/test/test_10252.jpg
#   inflating: ./open/image/test/test_04321.jpg
#   inflating: ./open/image/test/test_02474.jpg
#   inflating: ./open/image/test/test_02857.jpg
#   inflating: ./open/image/test/test_02282.jpg
#   inflating: ./open/image/test/test_06382.jpg
#   inflating: ./open/image/test/test_06581.jpg
#   inflating: ./open/image/test/test_08028.jpg
#   inflating: ./open/image/test/test_04689.jpg
#   inflating: ./open/image/test/test_03754.jpg
#   inflating: ./open/image/test/test_02967.jpg
#   inflating: ./open/image/test/test_02269.jpg
#   inflating: ./open/image/test/test_04184.jpg
#   inflating: ./open/image/test/test_04395.jpg
#   inflating: ./open/image/test/test_11736.jpg
#   inflating: ./open/image/test/test_00868.jpg
#   inflating: ./open/image/test/test_01210.jpg
#   inflating: ./open/image/test/test_02286.jpg
#   inflating: ./open/image/test/test_09484.jpg
#   inflating: ./open/image/test/test_07124.jpg
#   inflating: ./open/image/test/test_09615.jpg
#   inflating: ./open/image/test/test_04763.jpg
#   inflating: ./open/image/test/test_08525.jpg
#   inflating: ./open/image/test/test_09767.jpg
#   inflating: ./open/image/test/test_02114.jpg
#   inflating: ./open/image/test/test_04955.jpg
#   inflating: ./open/image/test/test_03338.jpg
#   inflating: ./open/image/test/test_05046.jpg
#   inflating: ./open/image/test/test_11754.jpg
#   inflating: ./open/image/test/test_06288.jpg
#   inflating: ./open/image/test/test_01918.jpg
#   inflating: ./open/image/test/test_04751.jpg
#   inflating: ./open/image/test/test_04926.jpg
#   inflating: ./open/image/test/test_11380.jpg
#   inflating: ./open/image/test/test_04744.jpg
#   inflating: ./open/image/test/test_01741.jpg
#   inflating: ./open/image/test/test_01400.jpg
#   inflating: ./open/image/test/test_08279.jpg
#   inflating: ./open/image/test/test_04633.jpg
#   inflating: ./open/image/test/test_01116.jpg
#   inflating: ./open/image/test/test_11709.jpg
#   inflating: ./open/image/test/test_06551.jpg
#   inflating: ./open/image/test/test_10885.jpg
#   inflating: ./open/image/test/test_11193.jpg
#   inflating: ./open/image/test/test_04852.jpg
#   inflating: ./open/image/test/test_00402.jpg
#   inflating: ./open/image/test/test_08747.jpg
#   inflating: ./open/image/test/test_10546.jpg
#   inflating: ./open/image/test/test_01715.jpg
#   inflating: ./open/image/test/test_10816.jpg
#   inflating: ./open/image/test/test_05893.jpg
#   inflating: ./open/image/test/test_02151.jpg
#   inflating: ./open/image/test/test_07548.jpg
#   inflating: ./open/image/test/test_04593.jpg
#   inflating: ./open/image/test/test_00746.jpg
#   inflating: ./open/image/test/test_06776.jpg
#   inflating: ./open/image/test/test_11679.jpg
#   inflating: ./open/image/test/test_07021.jpg
#   inflating: ./open/image/test/test_05200.jpg
#   inflating: ./open/image/test/test_03766.jpg
#   inflating: ./open/image/test/test_08481.jpg
#   inflating: ./open/image/test/test_03805.jpg
#   inflating: ./open/image/test/test_03404.jpg
#   inflating: ./open/image/test/test_03999.jpg
#   inflating: ./open/image/test/test_07895.jpg
#   inflating: ./open/image/test/test_10351.jpg
#   inflating: ./open/image/test/test_05090.jpg
#   inflating: ./open/image/test/test_09905.jpg
#   inflating: ./open/image/test/test_07228.jpg
#   inflating: ./open/image/test/test_09956.jpg
#   inflating: ./open/image/test/test_03952.jpg
#   inflating: ./open/image/test/test_02721.jpg
#   inflating: ./open/image/test/test_02462.jpg
#   inflating: ./open/image/test/test_05645.jpg
#   inflating: ./open/image/test/test_07963.jpg
#   inflating: ./open/image/test/test_04093.jpg
#   inflating: ./open/image/test/test_11075.jpg
#   inflating: ./open/image/test/test_11808.jpg
#   inflating: ./open/image/test/test_05738.jpg
#   inflating: ./open/image/test/test_04688.jpg
#   inflating: ./open/image/test/test_04802.jpg
#   inflating: ./open/image/test/test_04305.jpg
#   inflating: ./open/image/test/test_09038.jpg
#   inflating: ./open/image/test/test_11906.jpg
#   inflating: ./open/image/test/test_01264.jpg
#   inflating: ./open/image/test/test_07428.jpg
#   inflating: ./open/image/test/test_07245.jpg
#   inflating: ./open/image/test/test_09818.jpg
#   inflating: ./open/image/test/test_07003.jpg
#   inflating: ./open/image/test/test_10301.jpg
#   inflating: ./open/image/test/test_10735.jpg
#   inflating: ./open/image/test/test_03325.jpg
#   inflating: ./open/image/test/test_07681.jpg
#   inflating: ./open/image/test/test_02754.jpg
#   inflating: ./open/image/test/test_03816.jpg
#   inflating: ./open/image/test/test_10837.jpg
#   inflating: ./open/image/test/test_10551.jpg
#   inflating: ./open/image/test/test_08941.jpg
#   inflating: ./open/image/test/test_10457.jpg
#   inflating: ./open/image/test/test_04298.jpg
#   inflating: ./open/image/test/test_04287.jpg
#   inflating: ./open/image/test/test_05065.jpg
#   inflating: ./open/image/test/test_06362.jpg
#   inflating: ./open/image/test/test_01172.jpg
#   inflating: ./open/image/test/test_04417.jpg
#   inflating: ./open/image/test/test_04559.jpg
#   inflating: ./open/image/test/test_03475.jpg
#   inflating: ./open/image/test/test_09150.jpg
#   inflating: ./open/image/test/test_11761.jpg
#   inflating: ./open/image/test/test_02834.jpg
#   inflating: ./open/image/test/test_10690.jpg
#   inflating: ./open/image/test/test_10763.jpg
#   inflating: ./open/image/test/test_08950.jpg
#   inflating: ./open/image/test/test_03329.jpg
#   inflating: ./open/image/test/test_03043.jpg
#   inflating: ./open/image/test/test_10773.jpg
#   inflating: ./open/image/test/test_01252.jpg
#   inflating: ./open/image/test/test_02386.jpg
#   inflating: ./open/image/test/test_04691.jpg
#   inflating: ./open/image/test/test_00624.jpg
#   inflating: ./open/image/test/test_10815.jpg
#   inflating: ./open/image/test/test_06198.jpg
#   inflating: ./open/image/test/test_11851.jpg
#   inflating: ./open/image/test/test_02487.jpg
#   inflating: ./open/image/test/test_01214.jpg
#   inflating: ./open/image/test/test_10058.jpg
#   inflating: ./open/image/test/test_05320.jpg
#   inflating: ./open/image/test/test_05563.jpg
#   inflating: ./open/image/test/test_03871.jpg
#   inflating: ./open/image/test/test_01719.jpg
#   inflating: ./open/image/test/test_07497.jpg
#   inflating: ./open/image/test/test_10869.jpg
#   inflating: ./open/image/test/test_05859.jpg
#   inflating: ./open/image/test/test_00826.jpg
#   inflating: ./open/image/test/test_02198.jpg
#   inflating: ./open/image/test/test_06221.jpg
#   inflating: ./open/image/test/test_11094.jpg
#   inflating: ./open/image/test/test_06246.jpg
#   inflating: ./open/image/test/test_02203.jpg
#   inflating: ./open/image/test/test_03035.jpg
#   inflating: ./open/image/test/test_07125.jpg
#   inflating: ./open/image/test/test_04796.jpg
#   inflating: ./open/image/test/test_02380.jpg
#   inflating: ./open/image/test/test_05378.jpg
#   inflating: ./open/image/test/test_02388.jpg
#   inflating: ./open/image/test/test_06409.jpg
#   inflating: ./open/image/test/test_03595.jpg
#   inflating: ./open/image/test/test_04757.jpg
#   inflating: ./open/image/test/test_05352.jpg
#   inflating: ./open/image/test/test_01866.jpg
#   inflating: ./open/image/test/test_00503.jpg
#   inflating: ./open/image/test/test_09558.jpg
#   inflating: ./open/image/test/test_05409.jpg
#   inflating: ./open/image/test/test_10484.jpg
#   inflating: ./open/image/test/test_05410.jpg
#   inflating: ./open/image/test/test_06664.jpg
#   inflating: ./open/image/test/test_04642.jpg
#   inflating: ./open/image/test/test_05990.jpg
#   inflating: ./open/image/test/test_03487.jpg
#   inflating: ./open/image/test/test_00104.jpg
#   inflating: ./open/image/test/test_03870.jpg
#   inflating: ./open/image/test/test_01402.jpg
#   inflating: ./open/image/test/test_10550.jpg
#   inflating: ./open/image/test/test_02983.jpg
#   inflating: ./open/image/test/test_09882.jpg
#   inflating: ./open/image/test/test_02725.jpg
#   inflating: ./open/image/test/test_02211.jpg
#   inflating: ./open/image/test/test_05486.jpg
#   inflating: ./open/image/test/test_05729.jpg
#   inflating: ./open/image/test/test_05209.jpg
#   inflating: ./open/image/test/test_01706.jpg
#   inflating: ./open/image/test/test_07165.jpg
#   inflating: ./open/image/test/test_10537.jpg
#   inflating: ./open/image/test/test_02392.jpg
#   inflating: ./open/image/test/test_07844.jpg
#   inflating: ./open/image/test/test_00033.jpg
#   inflating: ./open/image/test/test_03006.jpg
#   inflating: ./open/image/test/test_01884.jpg
#   inflating: ./open/image/test/test_03290.jpg
#   inflating: ./open/image/test/test_05942.jpg
#   inflating: ./open/image/test/test_05686.jpg
#   inflating: ./open/image/test/test_08785.jpg
#   inflating: ./open/image/test/test_06918.jpg
#   inflating: ./open/image/test/test_00935.jpg
#   inflating: ./open/image/test/test_00264.jpg
#   inflating: ./open/image/test/test_04985.jpg
#   inflating: ./open/image/test/test_09402.jpg
#   inflating: ./open/image/test/test_01316.jpg
#   inflating: ./open/image/test/test_04338.jpg
#   inflating: ./open/image/test/test_04418.jpg
#   inflating: ./open/image/test/test_09716.jpg
#   inflating: ./open/image/test/test_00048.jpg
#   inflating: ./open/image/test/test_04774.jpg
#   inflating: ./open/image/test/test_10433.jpg
#   inflating: ./open/image/test/test_01751.jpg
#   inflating: ./open/image/test/test_11276.jpg
#   inflating: ./open/image/test/test_05759.jpg
#   inflating: ./open/image/test/test_04013.jpg
#   inflating: ./open/image/test/test_08176.jpg
#   inflating: ./open/image/test/test_03529.jpg
#   inflating: ./open/image/test/test_05891.jpg
#   inflating: ./open/image/test/test_08370.jpg
#   inflating: ./open/image/test/test_05691.jpg
#   inflating: ./open/image/test/test_11666.jpg
#   inflating: ./open/image/test/test_07683.jpg
#   inflating: ./open/image/test/test_09533.jpg
#   inflating: ./open/image/test/test_07764.jpg
#   inflating: ./open/image/test/test_06069.jpg
#   inflating: ./open/image/test/test_09536.jpg
#   inflating: ./open/image/test/test_03617.jpg
#   inflating: ./open/image/test/test_09681.jpg
#   inflating: ./open/image/test/test_04910.jpg
#   inflating: ./open/image/test/test_07801.jpg
#   inflating: ./open/image/test/test_07053.jpg
#   inflating: ./open/image/test/test_04089.jpg
#   inflating: ./open/image/test/test_01833.jpg
#   inflating: ./open/image/test/test_00045.jpg
#   inflating: ./open/image/test/test_11346.jpg
#   inflating: ./open/image/test/test_07305.jpg
#   inflating: ./open/image/test/test_04457.jpg
#   inflating: ./open/image/test/test_09874.jpg
#   inflating: ./open/image/test/test_01203.jpg
#   inflating: ./open/image/test/test_02586.jpg
#   inflating: ./open/image/test/test_06000.jpg
#   inflating: ./open/image/test/test_07722.jpg
#   inflating: ./open/image/test/test_07149.jpg
#   inflating: ./open/image/test/test_10501.jpg
#   inflating: ./open/image/test/test_01107.jpg
#   inflating: ./open/image/test/test_11448.jpg
#   inflating: ./open/image/test/test_00958.jpg
#   inflating: ./open/image/test/test_10698.jpg
#   inflating: ./open/image/test/test_08700.jpg
#   inflating: ./open/image/test/test_04146.jpg
#   inflating: ./open/image/test/test_02103.jpg
#   inflating: ./open/image/test/test_07905.jpg
#   inflating: ./open/image/test/test_04770.jpg
#   inflating: ./open/image/test/test_09736.jpg
#   inflating: ./open/image/test/test_09871.jpg
#   inflating: ./open/image/test/test_08075.jpg
#   inflating: ./open/image/test/test_10093.jpg
#   inflating: ./open/image/test/test_07833.jpg
#   inflating: ./open/image/test/test_01565.jpg
#   inflating: ./open/image/test/test_05622.jpg
#   inflating: ./open/image/test/test_03780.jpg
#   inflating: ./open/image/test/test_01430.jpg
#   inflating: ./open/image/test/test_02305.jpg
#   inflating: ./open/image/test/test_06677.jpg
#   inflating: ./open/image/test/test_11063.jpg
#   inflating: ./open/image/test/test_10076.jpg
#   inflating: ./open/image/test/test_04248.jpg
#   inflating: ./open/image/test/test_07222.jpg
#   inflating: ./open/image/test/test_02689.jpg
#   inflating: ./open/image/test/test_08405.jpg
#   inflating: ./open/image/test/test_02146.jpg
#   inflating: ./open/image/test/test_10430.jpg
#   inflating: ./open/image/test/test_00640.jpg
#   inflating: ./open/image/test/test_03232.jpg
#   inflating: ./open/image/test/test_11109.jpg
#   inflating: ./open/image/test/test_01275.jpg
#   inflating: ./open/image/test/test_10544.jpg
#   inflating: ./open/image/test/test_00617.jpg
#   inflating: ./open/image/test/test_05238.jpg
#   inflating: ./open/image/test/test_00288.jpg
#   inflating: ./open/image/test/test_11045.jpg
#   inflating: ./open/image/test/test_07453.jpg
#   inflating: ./open/image/test/test_09639.jpg
#   inflating: ./open/image/test/test_03151.jpg
#   inflating: ./open/image/test/test_11907.jpg
#   inflating: ./open/image/test/test_06275.jpg
#   inflating: ./open/image/test/test_01230.jpg
#   inflating: ./open/image/test/test_05272.jpg
#   inflating: ./open/image/test/test_01463.jpg
#   inflating: ./open/image/test/test_06445.jpg
#   inflating: ./open/image/test/test_07550.jpg
#   inflating: ./open/image/test/test_10892.jpg
#   inflating: ./open/image/test/test_08708.jpg
#   inflating: ./open/image/test/test_10182.jpg
#   inflating: ./open/image/test/test_06287.jpg
#   inflating: ./open/image/test/test_08216.jpg
#   inflating: ./open/image/test/test_11183.jpg
#   inflating: ./open/image/test/test_08734.jpg
#   inflating: ./open/image/test/test_07757.jpg
#   inflating: ./open/image/test/test_02518.jpg
#   inflating: ./open/image/test/test_06946.jpg
#   inflating: ./open/image/test/test_06285.jpg
#   inflating: ./open/image/test/test_06964.jpg
#   inflating: ./open/image/test/test_01845.jpg
#   inflating: ./open/image/test/test_06160.jpg
#   inflating: ./open/image/test/test_02479.jpg
#   inflating: ./open/image/test/test_01702.jpg
#   inflating: ./open/image/test/test_09872.jpg
#   inflating: ./open/image/test/test_01421.jpg
#   inflating: ./open/image/test/test_11166.jpg
#   inflating: ./open/image/test/test_04607.jpg
#   inflating: ./open/image/test/test_07661.jpg
#   inflating: ./open/image/test/test_04835.jpg
#   inflating: ./open/image/test/test_00907.jpg
#   inflating: ./open/image/test/test_08827.jpg
#   inflating: ./open/image/test/test_03649.jpg
#   inflating: ./open/image/test/test_08985.jpg
#   inflating: ./open/image/test/test_02290.jpg
#   inflating: ./open/image/test/test_01955.jpg
#   inflating: ./open/image/test/test_05666.jpg
#   inflating: ./open/image/test/test_08978.jpg
#   inflating: ./open/image/test/test_03433.jpg
#   inflating: ./open/image/test/test_04029.jpg
#   inflating: ./open/image/test/test_06576.jpg
#   inflating: ./open/image/test/test_05574.jpg
#   inflating: ./open/image/test/test_02936.jpg
#   inflating: ./open/image/test/test_04563.jpg
#   inflating: ./open/image/test/test_09684.jpg
#   inflating: ./open/image/test/test_06378.jpg
#   inflating: ./open/image/test/test_05083.jpg
#   inflating: ./open/image/test/test_11719.jpg
#   inflating: ./open/image/test/test_06832.jpg
#   inflating: ./open/image/test/test_07689.jpg
#   inflating: ./open/image/test/test_04270.jpg
#   inflating: ./open/image/test/test_06835.jpg
#   inflating: ./open/image/test/test_04138.jpg
#   inflating: ./open/image/test/test_05697.jpg
#   inflating: ./open/image/test/test_11412.jpg
#   inflating: ./open/image/test/test_07429.jpg
#   inflating: ./open/image/test/test_02780.jpg
#   inflating: ./open/image/test/test_00930.jpg
#   inflating: ./open/image/test/test_11647.jpg
#   inflating: ./open/image/test/test_08188.jpg
#   inflating: ./open/image/test/test_05915.jpg
#   inflating: ./open/image/test/test_04808.jpg
#   inflating: ./open/image/test/test_09634.jpg
#   inflating: ./open/image/test/test_02655.jpg
#   inflating: ./open/image/test/test_10791.jpg
#   inflating: ./open/image/test/test_11170.jpg
#   inflating: ./open/image/test/test_07469.jpg
#   inflating: ./open/image/test/test_04292.jpg
#   inflating: ./open/image/test/test_07051.jpg
#   inflating: ./open/image/test/test_04086.jpg
#   inflating: ./open/image/test/test_05171.jpg
#   inflating: ./open/image/test/test_04662.jpg
#   inflating: ./open/image/test/test_07747.jpg
#   inflating: ./open/image/test/test_05208.jpg
#   inflating: ./open/image/test/test_11137.jpg
#   inflating: ./open/image/test/test_08604.jpg
#   inflating: ./open/image/test/test_08983.jpg
#   inflating: ./open/image/test/test_05104.jpg
#   inflating: ./open/image/test/test_11061.jpg
#   inflating: ./open/image/test/test_09451.jpg
#   inflating: ./open/image/test/test_06591.jpg
#   inflating: ./open/image/test/test_06505.jpg
#   inflating: ./open/image/test/test_04777.jpg
#   inflating: ./open/image/test/test_01561.jpg
#   inflating: ./open/image/test/test_03776.jpg
#   inflating: ./open/image/test/test_07939.jpg
#   inflating: ./open/image/test/test_08896.jpg
#   inflating: ./open/image/test/test_11291.jpg
#   inflating: ./open/image/test/test_07750.jpg
#   inflating: ./open/image/test/test_10818.jpg
#   inflating: ./open/image/test/test_07851.jpg
#   inflating: ./open/image/test/test_02793.jpg
#   inflating: ./open/image/test/test_11491.jpg
#   inflating: ./open/image/test/test_11801.jpg
#   inflating: ./open/image/test/test_10940.jpg
#   inflating: ./open/image/test/test_05913.jpg
#   inflating: ./open/image/test/test_06267.jpg
#   inflating: ./open/image/test/test_10718.jpg
#   inflating: ./open/image/test/test_09929.jpg
#   inflating: ./open/image/test/test_00815.jpg
#   inflating: ./open/image/test/test_03877.jpg
#   inflating: ./open/image/test/test_03672.jpg
#   inflating: ./open/image/test/test_06684.jpg
#   inflating: ./open/image/test/test_04320.jpg
#   inflating: ./open/image/test/test_00571.jpg
#   inflating: ./open/image/test/test_03690.jpg
#   inflating: ./open/image/test/test_04115.jpg
#   inflating: ./open/image/test/test_00577.jpg
#   inflating: ./open/image/test/test_07870.jpg
#   inflating: ./open/image/test/test_01328.jpg
#   inflating: ./open/image/test/test_07983.jpg
#   inflating: ./open/image/test/test_08558.jpg
#   inflating: ./open/image/test/test_04060.jpg
#   inflating: ./open/image/test/test_08854.jpg
#   inflating: ./open/image/test/test_08138.jpg
#   inflating: ./open/image/test/test_02055.jpg
#   inflating: ./open/image/test/test_04665.jpg
#   inflating: ./open/image/test/test_00772.jpg
#   inflating: ./open/image/test/test_08174.jpg
#   inflating: ./open/image/test/test_00460.jpg
#   inflating: ./open/image/test/test_04571.jpg
#   inflating: ./open/image/test/test_03950.jpg
#   inflating: ./open/image/test/test_07063.jpg
#   inflating: ./open/image/test/test_00905.jpg
#   inflating: ./open/image/test/test_01548.jpg
#   inflating: ./open/image/test/test_10209.jpg
#   inflating: ./open/image/test/test_00466.jpg
#   inflating: ./open/image/test/test_11325.jpg
#   inflating: ./open/image/test/test_01536.jpg
#   inflating: ./open/image/test/test_11535.jpg
#   inflating: ./open/image/test/test_10809.jpg
#   inflating: ./open/image/test/test_01769.jpg
#   inflating: ./open/image/test/test_10562.jpg
#   inflating: ./open/image/test/test_04718.jpg
#   inflating: ./open/image/test/test_00586.jpg
#   inflating: ./open/image/test/test_02600.jpg
#   inflating: ./open/image/test/test_03948.jpg
#   inflating: ./open/image/test/test_11880.jpg
#   inflating: ./open/image/test/test_02798.jpg
#   inflating: ./open/image/test/test_10471.jpg
#   inflating: ./open/image/test/test_02188.jpg
#   inflating: ./open/image/test/test_09114.jpg
#   inflating: ./open/image/test/test_03531.jpg
#   inflating: ./open/image/test/test_08192.jpg
#   inflating: ./open/image/test/test_10459.jpg
#   inflating: ./open/image/test/test_06348.jpg
#   inflating: ./open/image/test/test_01811.jpg
#   inflating: ./open/image/test/test_06554.jpg
#   inflating: ./open/image/test/test_06651.jpg
#   inflating: ./open/image/test/test_09735.jpg
#   inflating: ./open/image/test/test_10941.jpg
#   inflating: ./open/image/test/test_06068.jpg
#   inflating: ./open/image/test/test_05862.jpg
#   inflating: ./open/image/test/test_08974.jpg
#   inflating: ./open/image/test/test_09881.jpg
#   inflating: ./open/image/test/test_08990.jpg
#   inflating: ./open/image/test/test_11457.jpg
#   inflating: ./open/image/test/test_06224.jpg
#   inflating: ./open/image/test/test_02196.jpg
#   inflating: ./open/image/test/test_03184.jpg
#   inflating: ./open/image/test/test_05157.jpg
#   inflating: ./open/image/test/test_07562.jpg
#   inflating: ./open/image/test/test_03111.jpg
#   inflating: ./open/image/test/test_06637.jpg
#   inflating: ./open/image/test/test_05965.jpg
#   inflating: ./open/image/test/test_09452.jpg
#   inflating: ./open/image/test/test_07666.jpg
#   inflating: ./open/image/test/test_00367.jpg
#   inflating: ./open/image/test/test_11279.jpg
#   inflating: ./open/image/test/test_03189.jpg
#   inflating: ./open/image/test/test_06905.jpg
#   inflating: ./open/image/test/test_09122.jpg
#   inflating: ./open/image/test/test_07653.jpg
#   inflating: ./open/image/test/test_11338.jpg
# ...
#   inflating: ./open/image/test/test_02067.jpg
#   inflating: ./open/image/test/test_00480.jpg
#   inflating: ./open/image/test/test_03327.jpg
#   inflating: ./open/image/test/test_10579.jpg
#   inflating: ./open/image/test/test_02440.jpg
#   inflating: ./open/image/test/test_04217.jpg
#   inflating: ./open/image/test/test_00954.jpg
#   inflating: ./open/image/test/test_11896.jpg
#   inflating: ./open/image/test/test_03576.jpg
#   inflating: ./open/image/test/test_03922.jpg
#   inflating: ./open/image/test/test_03522.jpg
#   inflating: ./open/image/test/test_04776.jpg
#   inflating: ./open/image/test/test_05457.jpg
#   inflating: ./open/image/test/test_08535.jpg
#   inflating: ./open/image/test/test_06400.jpg
#   inflating: ./open/image/test/test_08787.jpg
#   inflating: ./open/image/test/test_11447.jpg
#   inflating: ./open/image/test/test_00206.jpg
#   inflating: ./open/image/test/test_08903.jpg
#   inflating: ./open/image/test/test_06639.jpg
#   inflating: ./open/image/test/test_02858.jpg
#   inflating: ./open/image/test/test_00224.jpg
#   inflating: ./open/image/test/test_11440.jpg
#   inflating: ./open/image/test/test_08703.jpg
#   inflating: ./open/image/test/test_08847.jpg
#   inflating: ./open/image/test/test_07326.jpg
#   inflating: ./open/image/test/test_05823.jpg
#   inflating: ./open/image/test/test_00909.jpg
#   inflating: ./open/image/test/test_09360.jpg
#   inflating: ./open/image/test/test_10197.jpg
#   inflating: ./open/image/test/test_09688.jpg
#   inflating: ./open/image/test/test_06041.jpg
#   inflating: ./open/image/test/test_00179.jpg
#   inflating: ./open/image/test/test_00675.jpg
#   inflating: ./open/image/test/test_04408.jpg
#   inflating: ./open/image/test/test_10038.jpg
#   inflating: ./open/image/test/test_04462.jpg
#   inflating: ./open/image/test/test_04773.jpg
#   inflating: ./open/image/test/test_08910.jpg
#   inflating: ./open/image/test/test_06387.jpg
#   inflating: ./open/image/test/test_06254.jpg
#   inflating: ./open/image/test/test_02371.jpg
#   inflating: ./open/image/test/test_10395.jpg
#   inflating: ./open/image/test/test_11162.jpg
#   inflating: ./open/image/test/test_11364.jpg
#   inflating: ./open/image/test/test_03428.jpg
#   inflating: ./open/image/test/test_03535.jpg
#   inflating: ./open/image/test/test_10661.jpg
#   inflating: ./open/image/test/test_09277.jpg
#   inflating: ./open/image/test/test_08230.jpg
#   inflating: ./open/image/test/test_07985.jpg
#   inflating: ./open/image/test/test_08107.jpg
#   inflating: ./open/image/test/test_01020.jpg
#   inflating: ./open/image/test/test_01781.jpg
#   inflating: ./open/image/test/test_01724.jpg
#   inflating: ./open/image/test/test_11568.jpg
#   inflating: ./open/image/test/test_00991.jpg
#   inflating: ./open/image/test/test_05506.jpg
#   inflating: ./open/image/test/test_00842.jpg
#   inflating: ./open/image/test/test_08134.jpg
#   inflating: ./open/image/test/test_04059.jpg
#   inflating: ./open/image/test/test_11226.jpg
#   inflating: ./open/image/test/test_02259.jpg
#   inflating: ./open/image/test/test_11828.jpg
#   inflating: ./open/image/test/test_06414.jpg
#   inflating: ./open/image/test/test_04831.jpg
#   inflating: ./open/image/test/test_06178.jpg
#   inflating: ./open/image/test/test_03223.jpg
#   inflating: ./open/image/test/test_11460.jpg
#   inflating: ./open/image/test/test_08946.jpg
#   inflating: ./open/image/test/test_02260.jpg
#   inflating: ./open/image/test/test_05476.jpg
#   inflating: ./open/image/test/test_06515.jpg
#   inflating: ./open/image/test/test_00572.jpg
#   inflating: ./open/image/test/test_01736.jpg
#   inflating: ./open/image/test/test_11738.jpg
#   inflating: ./open/image/test/test_03417.jpg
#   inflating: ./open/image/test/test_04783.jpg
#   inflating: ./open/image/test/test_08233.jpg
#   inflating: ./open/image/test/test_06170.jpg
#   inflating: ./open/image/test/test_04973.jpg
#   inflating: ./open/image/test/test_03918.jpg
#   inflating: ./open/image/test/test_03552.jpg
#   inflating: ./open/image/test/test_10739.jpg
#   inflating: ./open/image/test/test_03536.jpg
#   inflating: ./open/image/test/test_07037.jpg
#   inflating: ./open/image/test/test_05340.jpg
#   inflating: ./open/image/test/test_02647.jpg
#   inflating: ./open/image/test/test_07498.jpg
#   inflating: ./open/image/test/test_06805.jpg
#   inflating: ./open/image/test/test_07325.jpg
#   inflating: ./open/image/test/test_03149.jpg
#   inflating: ./open/image/test/test_01878.jpg
#   inflating: ./open/image/test/test_09640.jpg
#   inflating: ./open/image/test/test_01229.jpg
#   inflating: ./open/image/test/test_09970.jpg
#   inflating: ./open/image/test/test_05703.jpg
#   inflating: ./open/image/test/test_06418.jpg
#   inflating: ./open/image/test/test_02072.jpg
#   inflating: ./open/image/test/test_11237.jpg
#   inflating: ./open/image/test/test_11553.jpg
#   inflating: ./open/image/test/test_08880.jpg
#   inflating: ./open/image/test/test_08492.jpg
#   inflating: ./open/image/test/test_03982.jpg
#   inflating: ./open/image/test/test_06999.jpg
#   inflating: ./open/image/test/test_02675.jpg
#   inflating: ./open/image/test/test_11697.jpg
#   inflating: ./open/image/test/test_09967.jpg
#   inflating: ./open/image/test/test_00547.jpg
#   inflating: ./open/image/test/test_04148.jpg
#   inflating: ./open/image/test/test_11253.jpg
#   inflating: ./open/image/test/test_06374.jpg
#   inflating: ./open/image/test/test_02801.jpg
#   inflating: ./open/image/test/test_08408.jpg
#   inflating: ./open/image/test/test_11531.jpg
#   inflating: ./open/image/test/test_10236.jpg
#   inflating: ./open/image/test/test_01474.jpg
#   inflating: ./open/image/test/test_01562.jpg
#   inflating: ./open/image/test/test_09973.jpg
#   inflating: ./open/image/test/test_00817.jpg
#   inflating: ./open/image/test/test_00058.jpg
#   inflating: ./open/image/test/test_09454.jpg
#   inflating: ./open/image/test/test_02156.jpg
#   inflating: ./open/image/test/test_10124.jpg
#   inflating: ./open/image/test/test_04630.jpg
#   inflating: ./open/image/test/test_05888.jpg
#   inflating: ./open/image/test/test_00645.jpg
#   inflating: ./open/image/test/test_01725.jpg
#   inflating: ./open/image/test/test_10460.jpg
#   inflating: ./open/image/test/test_11164.jpg
#   inflating: ./open/image/test/test_05722.jpg
#   inflating: ./open/image/test/test_03482.jpg
#   inflating: ./open/image/test/test_11749.jpg
#   inflating: ./open/image/test/test_02540.jpg
#   inflating: ./open/image/test/test_11158.jpg
#   inflating: ./open/image/test/test_03353.jpg
#   inflating: ./open/image/test/test_11465.jpg
#   inflating: ./open/image/test/test_00921.jpg
#   inflating: ./open/image/test/test_04026.jpg
#   inflating: ./open/image/test/test_10841.jpg
#   inflating: ./open/image/test/test_09027.jpg
#   inflating: ./open/image/test/test_09790.jpg
#   inflating: ./open/image/test/test_03425.jpg
#   inflating: ./open/image/test/test_02699.jpg
#   inflating: ./open/image/test/test_11375.jpg
#   inflating: ./open/image/test/test_11426.jpg
#   inflating: ./open/image/test/test_09160.jpg
#   inflating: ./open/image/test/test_09830.jpg
#   inflating: ./open/image/test/test_01579.jpg
#   inflating: ./open/image/test/test_00636.jpg
#   inflating: ./open/image/test/test_00961.jpg
#   inflating: ./open/image/test/test_07774.jpg
#   inflating: ./open/image/test/test_01616.jpg
#   inflating: ./open/image/test/test_08342.jpg
#   inflating: ./open/image/test/test_07828.jpg
#   inflating: ./open/image/test/test_00820.jpg
#   inflating: ./open/image/test/test_02802.jpg
#   inflating: ./open/image/test/test_06036.jpg
#   inflating: ./open/image/test/test_10567.jpg
#   inflating: ./open/image/test/test_03066.jpg
#   inflating: ./open/image/test/test_09548.jpg
#   inflating: ./open/image/test/test_02405.jpg
#   inflating: ./open/image/test/test_03590.jpg
#   inflating: ./open/image/test/test_00021.jpg
#   inflating: ./open/image/test/test_09924.jpg
#   inflating: ./open/image/test/test_05496.jpg
#   inflating: ./open/image/test/test_06329.jpg
#   inflating: ./open/image/test/test_04231.jpg
#   inflating: ./open/image/test/test_03804.jpg
#   inflating: ./open/image/test/test_07292.jpg
#   inflating: ./open/image/test/test_10195.jpg
#   inflating: ./open/image/test/test_07971.jpg
#   inflating: ./open/image/test/test_10002.jpg
#   inflating: ./open/image/test/test_02612.jpg
#   inflating: ./open/image/test/test_06807.jpg
#   inflating: ./open/image/test/test_02070.jpg
#   inflating: ./open/image/test/test_00629.jpg
#   inflating: ./open/image/test/test_09677.jpg
#   inflating: ./open/image/test/test_04349.jpg
#   inflating: ./open/image/test/test_07714.jpg
#   inflating: ./open/image/test/test_04479.jpg
#   inflating: ./open/image/test/test_07139.jpg
#   inflating: ./open/image/test/test_02004.jpg
#   inflating: ./open/image/test/test_05655.jpg
#   inflating: ./open/image/test/test_02099.jpg
#   inflating: ./open/image/test/test_04543.jpg
#   inflating: ./open/image/test/test_09278.jpg
#   inflating: ./open/image/test/test_06537.jpg
#   inflating: ./open/image/test/test_08374.jpg
#   inflating: ./open/image/test/test_09336.jpg
#   inflating: ./open/image/test/test_01186.jpg
#   inflating: ./open/image/test/test_09938.jpg
#   inflating: ./open/image/test/test_06480.jpg
#   inflating: ./open/image/test/test_02985.jpg
#   inflating: ./open/image/test/test_04815.jpg
#   inflating: ./open/image/test/test_07934.jpg
#   inflating: ./open/image/test/test_07422.jpg
#   inflating: ./open/image/test/test_07233.jpg
#   inflating: ./open/image/test/test_08205.jpg
#   inflating: ./open/image/test/test_05411.jpg
#   inflating: ./open/image/test/test_03782.jpg
#   inflating: ./open/image/test/test_03586.jpg
#   inflating: ./open/image/test/test_05118.jpg
#   inflating: ./open/image/test/test_10326.jpg
#   inflating: ./open/image/test/test_05464.jpg
#   inflating: ./open/image/test/test_10682.jpg
#   inflating: ./open/image/test/test_01331.jpg
#   inflating: ./open/image/test/test_03601.jpg
#   inflating: ./open/image/test/test_05006.jpg
#   inflating: ./open/image/test/test_05587.jpg
#   inflating: ./open/image/test/test_02452.jpg
#   inflating: ./open/image/test/test_02271.jpg
#   inflating: ./open/image/test/test_01136.jpg
#   inflating: ./open/image/test/test_01519.jpg
#   inflating: ./open/image/test/test_05689.jpg
#   inflating: ./open/image/test/test_09569.jpg
#   inflating: ./open/image/test/test_11098.jpg
#   inflating: ./open/image/test/test_11688.jpg
#   inflating: ./open/image/test/test_03697.jpg
#   inflating: ./open/image/test/test_08073.jpg
#   inflating: ./open/image/test/test_03315.jpg
#   inflating: ./open/image/test/test_07258.jpg
#   inflating: ./open/image/test/test_05693.jpg
#   inflating: ./open/image/test/test_08231.jpg
#   inflating: ./open/image/test/test_01614.jpg
#   inflating: ./open/image/test/test_09349.jpg
#   inflating: ./open/image/test/test_05817.jpg
#   inflating: ./open/image/test/test_07859.jpg
#   inflating: ./open/image/test/test_06482.jpg
#   inflating: ./open/image/test/test_10110.jpg
#   inflating: ./open/image/test/test_01476.jpg
#   inflating: ./open/image/test/test_03059.jpg
#   inflating: ./open/image/test/test_00524.jpg
#   inflating: ./open/image/test/test_05719.jpg
#   inflating: ./open/image/test/test_05748.jpg
#   inflating: ./open/image/test/test_02580.jpg
#   inflating: ./open/image/test/test_11760.jpg
#   inflating: ./open/image/test/test_11382.jpg
#   inflating: ./open/image/test/test_08884.jpg
#   inflating: ./open/image/test/test_08835.jpg
#   inflating: ./open/image/test/test_09589.jpg
#   inflating: ./open/image/test/test_03457.jpg
#   inflating: ./open/image/test/test_03513.jpg
#   inflating: ./open/image/test/test_08572.jpg
#   inflating: ./open/image/test/test_05246.jpg
#   inflating: ./open/image/test/test_08760.jpg
#   inflating: ./open/image/test/test_04366.jpg
#   inflating: ./open/image/test/test_06627.jpg
#   inflating: ./open/image/test/test_11512.jpg
#   inflating: ./open/image/test/test_02433.jpg
#   inflating: ./open/image/test/test_00540.jpg
#   inflating: ./open/image/test/test_01656.jpg
#   inflating: ./open/image/test/test_00936.jpg
#   inflating: ./open/image/test/test_00713.jpg
#   inflating: ./open/image/test/test_07412.jpg
#   inflating: ./open/image/test/test_05980.jpg
#   inflating: ./open/image/test/test_08102.jpg
#   inflating: ./open/image/test/test_05377.jpg
#   inflating: ./open/image/test/test_10697.jpg
#   inflating: ./open/image/test/test_07283.jpg
#   inflating: ./open/image/test/test_07277.jpg
#   inflating: ./open/image/test/test_06707.jpg
#   inflating: ./open/image/test/test_09018.jpg
#   inflating: ./open/image/test/test_01874.jpg
#   inflating: ./open/image/test/test_09011.jpg
#   inflating: ./open/image/test/test_00966.jpg
#   inflating: ./open/image/test/test_05471.jpg
#   inflating: ./open/image/test/test_05289.jpg
#   inflating: ./open/image/test/test_02659.jpg
#   inflating: ./open/image/test/test_04251.jpg
#   inflating: ./open/image/test/test_03331.jpg
#   inflating: ./open/image/test/test_11712.jpg
#   inflating: ./open/image/test/test_06625.jpg
#   inflating: ./open/image/test/test_02874.jpg
#   inflating: ./open/image/test/test_08793.jpg
#   inflating: ./open/image/test/test_11454.jpg
#   inflating: ./open/image/test/test_05064.jpg
#   inflating: ./open/image/test/test_08191.jpg
#   inflating: ./open/image/test/test_02960.jpg
#   inflating: ./open/image/test/test_07622.jpg
#   inflating: ./open/image/test/test_04435.jpg
#   inflating: ./open/image/test/test_00870.jpg
#   inflating: ./open/image/test/test_11827.jpg
#   inflating: ./open/image/test/test_02247.jpg
#   inflating: ./open/image/test/test_09234.jpg
#   inflating: ./open/image/test/test_00924.jpg
#   inflating: ./open/image/test/test_01753.jpg
#   inflating: ./open/image/test/test_00998.jpg
#   inflating: ./open/image/test/test_01488.jpg
#   inflating: ./open/image/test/test_02926.jpg
#   inflating: ./open/image/test/test_07596.jpg
#   inflating: ./open/image/test/test_04592.jpg
#   inflating: ./open/image/test/test_08597.jpg
#   inflating: ./open/image/test/test_09302.jpg
#   inflating: ./open/image/test/test_04731.jpg
#   inflating: ./open/image/test/test_07011.jpg
#   inflating: ./open/image/test/test_08555.jpg
#   inflating: ./open/image/test/test_07966.jpg
#   inflating: ./open/image/test/test_07113.jpg
#   inflating: ./open/image/test/test_07538.jpg
#   inflating: ./open/image/test/test_11326.jpg
#   inflating: ./open/image/test/test_06674.jpg
#   inflating: ./open/image/test/test_07742.jpg
#   inflating: ./open/image/test/test_01939.jpg
#   inflating: ./open/image/test/test_02126.jpg
#   inflating: ./open/image/test/test_02395.jpg
#   inflating: ./open/image/test/test_06607.jpg
#   inflating: ./open/image/test/test_00238.jpg
#   inflating: ./open/image/test/test_03730.jpg
#   inflating: ./open/image/test/test_09354.jpg
#   inflating: ./open/image/test/test_10024.jpg
#   inflating: ./open/image/test/test_04619.jpg
#   inflating: ./open/image/test/test_04159.jpg
#   inflating: ./open/image/test/test_11221.jpg
#   inflating: ./open/image/test/test_00542.jpg
#   inflating: ./open/image/test/test_02906.jpg
#   inflating: ./open/image/test/test_01170.jpg
#   inflating: ./open/image/test/test_04274.jpg
#   inflating: ./open/image/test/test_03975.jpg
#   inflating: ./open/image/test/test_02900.jpg
#   inflating: ./open/image/test/test_11640.jpg
#   inflating: ./open/image/test/test_04383.jpg
#   inflating: ./open/image/test/test_11543.jpg
#   inflating: ./open/image/test/test_05420.jpg
#   inflating: ./open/image/test/test_00453.jpg
#   inflating: ./open/image/test/test_04434.jpg
#   inflating: ./open/image/test/test_03470.jpg
#   inflating: ./open/image/test/test_06491.jpg
#   inflating: ./open/image/test/test_01867.jpg
#   inflating: ./open/image/test/test_07379.jpg
#   inflating: ./open/image/test/test_01379.jpg
#   inflating: ./open/sample_submission.csv
#   inflating: ./open/test.csv
#   inflating: ./open/train.csv

# %% [markdown]
# ## Dataset

# %%
class VQADataset(Dataset):
    def __init__(self, df, tokenizer, transform, img_path, is_test=False):
        self.df = df
        self.tokenizer = tokenizer
        self.transform = transform
        self.img_path = img_path
        self.is_test = is_test

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        img_name = os.path.join(self.img_path, row['image_id'] + '.jpg') # 이미지
        image = Image.open(img_name).convert('RGB')
        image = self.transform(image)

        question = row['question'] # 질문
        question = self.tokenizer.encode_plus(
            question,
            truncation=True,
            add_special_tokens=True,
            max_length=32,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
        )

        if not self.is_test:
            answer = row['answer'] # 답변
            answer = self.tokenizer.encode_plus(
                answer,
                max_length=32,
                padding='max_length',
                truncation=True,
                return_tensors='pt')
            return {
                'image': image.squeeze(),
                'question': question['input_ids'].squeeze(),
                'answer': answer['input_ids'].squeeze()
            }
        else:
            return {
                'image': image,
                'question': question['input_ids'].squeeze(),
            }

# %% [markdown]
# ## Model

# %%
class VQAModel(nn.Module):
    def __init__(self, vocab_size):
        super(VQAModel, self).__init__()
        self.vocab_size = vocab_size
        self.vit = timm.create_model('vit_base_patch16_224', pretrained=True)
        config = resolve_data_config({}, model=self.vit)
        transform = create_transform(**config)

        # self.gpt2 = GPT2Model.from_pretrained('gpt2')
        # self.gpt2.resize_token_embeddings(vocab_size) # 추가한 [PAD] 토큰 반영

        self.bert = BertModel.from_pretrained("bert-base-uncased")
        self.bert.resize_token_embeddings(vocab_size)

        combined_features_size = 1000 + self.bert.config.hidden_size # resnet 출력 차원 + bert 출력 차원
        self.classifier = nn.Linear(combined_features_size, vocab_size)

    def forward(self, images, question):
        image_features = self.vit(images)
        image_features = image_features.view(image_features.size(0),-1)

        outputs = self.bert(question)
        output_features = outputs.last_hidden_state # [batch, sequence, hidden]

        image_features = image_features.unsqueeze(1).expand(-1, output_features.size(1),-1) # [batch, sequence, 1000]
        combined = torch.cat([image_features, output_features], dim=-1) # [batch, sequence, 1000+hidden]
        output = self.classifier(combined) # [batch, vocab_size]
        return output

# %% [markdown]
# ## DataLoader

# %%
# 데이터 불러오기
train_df = pd.read_csv('open/train.csv')
test_df = pd.read_csv('open/test.csv')
sample_submission = pd.read_csv('open/sample_submission.csv')
train_img_path = 'open/image/train'
test_img_path = 'open/image/test'

# dataset & dataloader
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
vocab_size = len(tokenizer)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_dataset = VQADataset(train_df, tokenizer, transform, train_img_path, is_test=False)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# ## Train & Inference

# %%
# device
import torch

device = torch.device("cuda")
print(f"current device is {device}")

def train(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0

    for data in tqdm(loader, total=len(loader)):
        images = data['image'].to(device)
        question = data['question'].to(device)
        answer = data['answer'].to(device)

        optimizer.zero_grad()
        #여기서 문제 발생
        outputs = model(images, question)

        # output: [batch, sequence, vocab], answer : [batch, sequence]
        loss = criterion(outputs.view(-1, outputs.size(-1)), answer.view(-1))
        total_loss += loss.item()

        loss.backward()
        optimizer.step()

    avg_loss = total_loss / len(loader)
    return avg_loss
# Out:
# current device is cuda

# %%
def inference(model, loader):
    model.eval()
    preds = []
    with torch.no_grad():
        for data in tqdm(loader, total=len(loader)):
            images = data['image'].to(device)
            question = data['question'].to(device)
            outputs = model(images, question) # [batch, sequence, vocab]
            _, pred = torch.max(outputs, dim=2) # values, indices = _, pred
            preds.extend(pred.cpu().numpy())

    return preds

# %% [markdown]
# ## Run!

# %%
# Model
model = VQAModel(vocab_size).to(device)

# Criterion and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=5e-5)

# Training loop
for epoch in range(1):
    avg_loss = train(model, train_loader, optimizer, criterion)
    print(f"Epoch: {epoch+1}, Loss: {avg_loss:.4f}")
# Out:
# Downloading model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
#   0%|          | 0/5618 [00:00<?, ?it/s]
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-eecaaf5a78c5> in <cell line: 9>()
#       8 # Training loop
#       9 for epoch in range(1):
# ---> 10     avg_loss = train(model, train_loader, optimizer, criterion)
#      11     print(f"Epoch: {epoch+1}, Loss: {avg_loss:.4f}")
#
# <ipython-input-8-4797cee82973> in train(model, loader, optimizer, criterion)
#      16         optimizer.zero_grad()
#      17         #여기서 문제 발생
# ---> 18         outputs = model(images, question)
#      19
#      20         # output: [batch, sequence, vocab], answer : [batch, sequence]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-6-bf56e9065060> in forward(self, images, question)
#      20         image_features = image_features.view(image_features.size(0),-1)
#      21
# ---> 22         outputs = self.bert(question)
#      23         output_features = outputs.last_hidden_state # [batch, sequence, hidden]
#      24
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     968         elif input_ids is not None:
#     969             input_shape = input_ids.size()
# --> 970             self.warn_if_padding_and_no_attention_mask(input_ids, attention_mask)
#     971         elif inputs_embeds is not None:
#     972             input_shape = inputs_embeds.size()[:-1]
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in warn_if_padding_and_no_attention_mask(self, input_ids, attention_mask)
#    3488
#    3489         # Check only the first and last input IDs to reduce overhead.
# -> 3490         if self.config.pad_token_id in input_ids[:, [-1, 0]]:
#    3491             warn_string = (
#    3492                 "We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See "
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in __contains__(self, element)
#     984         return torch.from_numpy(array)
#     985
# --> 986     def __contains__(self, element):
#     987         r"""Check if `element` is present in tensor
#     988
#
# KeyboardInterrupt:

# %% [markdown]
# ## Post-Processing

# %%
# Dataset & DataLoader
test_dataset = VQADataset(test_df, tokenizer, transform, test_img_path, is_test=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# inference
preds = inference(model, test_loader)

no_pad_output = []
for pred in preds:
    output = pred[pred != 50257] # [PAD] token 제외
    no_pad_output.append(tokenizer.decode(output).strip()) # 토큰 id -> 토큰

# %% [markdown]
# ## Submission

# %%
sample_submission['answer'] = no_pad_output
sample_submission.to_csv('submission.csv', index=False)

# %%
solution = pd.read_csv('solution.csv')

# %% [markdown]
# ##Custom - Prompt

# %%
# Model
checkpoint = torch.load('baseline_2.pth')
model = checkpoint['model']
optimizer = checkpoint['optimizer']
epoch = checkpoint['epoch']

image_path = 'image/test'
image = 'test_00000'
question = input()
test_df = pd.DataFrame({"image_id":[image], "question":[question]})

test_dataset = VQADataset(test_df, tokenizer, transform, test_img_path, is_test=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
preds = inference(model, test_loader)
for pred in preds:
    output = pred[pred != 50257] # [PAD] token 제외

print('Question: ',question)
print('Answer: ', tokenizer.decode(output).strip()) # 토큰 id -> 토큰
Image.open(f'{image_path}/{image}.jpg').convert('RGB')
